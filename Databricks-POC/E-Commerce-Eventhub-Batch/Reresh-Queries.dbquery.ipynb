-- %%
-- Refresh all materialized views
REFRESH MATERIALIZED VIEW `na-dbxtraining`.biju_gold.top_brands_mv;
REFRESH MATERIALIZED VIEW `na-dbxtraining`.biju_gold.category_summary_mv;
REFRESH MATERIALIZED VIEW `na-dbxtraining`.biju_gold.location_ranking_mv;
REFRESH MATERIALIZED VIEW `na-dbxtraining`.biju_gold.mv_vip_customers_mv;
REFRESH MATERIALIZED VIEW `na-dbxtraining`.biju_gold.mv_brand_location_matrix_mv;
REFRESH MATERIALIZED VIEW `na-dbxtraining`.biju_gold.mv_discount_analysis_mv;
