# %%
# %sql
use catalog `na-dbxtraining`

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS `na-dbxtraining`.biju_bronze
MANAGED LOCATION 'abfss://landingzone-biju@dlsdbxtraining002.blob.core.windows.net/indatabricks/bronze';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS `na-dbxtraining`.biju_bronze
